# %%
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten, Embedding, concatenate, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import joblib
# Out:
# WARNING:tensorflow:From c:\ProgramData\anaconda3\envs\magisterka_env\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)

# %%
def clean_data(data):
    #transforming date variable
    data['date_GMT'] = pd.to_datetime(data['date_GMT'])
    data['date'] = pd.to_datetime(data['date_GMT'].dt.date)
    data['time'] = data['date_GMT'].dt.time
    
    #adding aggregated variables
    data['corners_total'] = data['home_team_corner_count'] + data['away_team_corner_count']
    data['yellow_cards_total'] = data['home_team_yellow_cards'] + data['away_team_yellow_cards']
    data['red_cards_total'] = data['home_team_red_cards'] + data['away_team_red_cards']
    data['cards_total'] = data['yellow_cards_total'] + data['red_cards_total']
    data['shots_total'] = data['home_team_shots'] + data['away_team_shots']
    data['shots_on_target_total'] = data['home_team_shots_on_target'] + data['away_team_shots_on_target']
    data['shots_off_target_total'] = data['home_team_shots_off_target'] + data['away_team_shots_off_target']
    data['fouls_total'] = data['home_team_fouls'] + data['away_team_fouls']
    
    #getting stadium names without city in brackets
    # data['base_name'] = data['stadium_name'].str.replace(r" \(.*\)$", "", regex=True)

    # city_map = data[data['stadium_name'].str.contains(r"\(.*\)")].copy()
    # city_map['city'] = city_map['stadium_name'].str.extract(r"\((.*?)\)")[0]
    # city_map = city_map.groupby('base_name')['city'].agg(pd.Series.mode).to_dict()

    # #filling stadium names without city in brackets
    # data['normalized_stadium'] = data.apply(lambda row: f"{row['base_name']} ({city_map.get(row['base_name'], 'Unknown')})" if '(' not in row['stadium_name'] else row['stadium_name'], axis=1)

    #dropping unnecessary features
    data.drop(['Unnamed: 0', 'timestamp', 'status', 'home_team_goal_timings', 'away_team_goal_timings', 'date_GMT'], axis=1, inplace=True)
    
    #setting one of the target variable - result of the game
    data['result'] = np.where(data['home_team_goal_count'] == data['away_team_goal_count'], 0, np.where(data['home_team_goal_count'] > data['away_team_goal_count'], 1, 2))
    
    def assign_season(date):
        year = date.year
        if date.month >= 8:  # Sezon zaczyna się w sierpniu
            return f'{str(year)[2:]}/{str(year+1)[2:]}'
        else:
            return f'{str(year-1)[2:]}/{str(year)[2:]}'
    
    data['season'] = data['date'].apply(assign_season)
    
    return data

# %%
data = pd.read_csv('./data/all_games.csv')

# %%
data = clean_data(data)
# Out:
# C:\Users\Łukasz\AppData\Local\Temp\ipykernel_7812\694537563.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['date_GMT'] = pd.to_datetime(data['date_GMT'])

# %% [markdown]
# # Data preprocessing

# %%
le = LabelEncoder()

# %%
data['home_team_encoded'] = le.fit_transform(data['home_team_name'])
data['away_team_encoded'] = le.fit_transform(data['away_team_name'])

# %%
# Przygotowanie danych wejściowych
X_home_team = data['home_team_encoded'].values
X_away_team = data['away_team_encoded'].values

# Wybrane cechy historyczne
historical_stats_columns = [
    'Pre-Match PPG (Home)', 'Pre-Match PPG (Away)', 'home_ppg', 'away_ppg',
    'home_team_goal_count', 'away_team_goal_count', 'total_goal_count', 'total_goals_at_half_time',
    'home_team_goal_count_half_time', 'away_team_goal_count_half_time', 'home_team_corner_count',
    'away_team_corner_count', 'home_team_yellow_cards', 'home_team_red_cards', 'away_team_yellow_cards',
    'away_team_red_cards', 'home_team_first_half_cards', 'home_team_second_half_cards',
    'away_team_first_half_cards', 'away_team_second_half_cards', 'home_team_shots', 'away_team_shots',
    'home_team_shots_on_target', 'away_team_shots_off_target', 'home_team_possession',
    'away_team_possession', 'Home Team Pre-Match xG', 'Away Team Pre-Match xG', 'team_a_xg', 'team_b_xg',
    'average_goals_per_match_pre_match', 'btts_percentage_pre_match', 'over_15_percentage_pre_match',
    'over_25_percentage_pre_match', 'over_35_percentage_pre_match', 'over_45_percentage_pre_match',
    'over_15_HT_FHG_percentage_pre_match', 'over_05_HT_FHG_percentage_pre_match', 'over_15_2HG_percentage_pre_match',
    'over_05_2HG_percentage_pre_match', 'average_corners_per_match_pre_match', 'average_cards_per_match_pre_match',
    'odds_ft_home_team_win', 'odds_ft_draw', 'odds_ft_away_team_win', 'odds_ft_over15', 'odds_ft_over25',
    'odds_ft_over35', 'odds_ft_over45', 'odds_btts_yes', 'odds_btts_no'
]
historical_stats = data[historical_stats_columns].values

# Przygotowanie danych wyjściowych
y_result = to_categorical(data['result'].values, num_classes=3)
y_total_goals = data['total_goal_count'].values
y_total_corners = data['corners_total'].values
y_total_cards = data['cards_total'].values

# Podział na zbiory treningowy i testowy
(X_home_team_train, X_home_team_test, 
 X_away_team_train, X_away_team_test, 
 historical_stats_train, historical_stats_test, 
 y_result_train, y_result_test, 
 y_total_goals_train, y_total_goals_test, 
 y_total_corners_train, y_total_corners_test, 
 y_total_cards_train, y_total_cards_test) = train_test_split(
    X_home_team, X_away_team, historical_stats, y_result, y_total_goals, y_total_corners, y_total_cards, 
    test_size=0.2, random_state=42)

# %%
y_result
# Out:
# array([[0., 1., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.],
#        ...,
#        [0., 1., 0.],
#        [0., 0., 1.],
#        [1., 0., 0.]], dtype=float32)

# %% [markdown]
# # FCNN

# %%
from keras.models import Model
from keras.layers import Input, Dense, Flatten, Embedding, concatenate, Dropout
from keras.regularizers import l2

num_teams = len(le.classes_)
input_shape_stats = historical_stats_train.shape[1]

# Wejścia
home_team_input = Input(shape=(1,))
away_team_input = Input(shape=(1,))
stats_input = Input(shape=(input_shape_stats,))

# Embedding dla drużyn
home_team_embedding = Embedding(input_dim=num_teams, output_dim=32)(home_team_input)
home_team_embedding = Flatten()(home_team_embedding)

away_team_embedding = Embedding(input_dim=num_teams, output_dim=32)(away_team_input)
away_team_embedding = Flatten()(away_team_embedding)

# Połączenie wszystkich wejść
merged = concatenate([home_team_embedding, away_team_embedding, stats_input])
merged = Dense(128, activation='relu', kernel_regularizer=l2(0.01))(merged)
merged = Dropout(0.5)(merged)
merged = Dense(64, activation='relu', kernel_regularizer=l2(0.01))(merged)
merged = Dropout(0.5)(merged)

# Warstwy wyjściowe
result_output = Dense(3, activation='softmax', name='result')(merged)
goals_output = Dense(1, activation='relu', name='total_goals')(merged)
corners_output = Dense(1, activation='relu', name='total_corners')(merged)
cards_output = Dense(1, activation='relu', name='total_cards')(merged)

# Tworzenie modelu
model = Model(inputs=[home_team_input, away_team_input, stats_input],
              outputs=[result_output, goals_output, corners_output, cards_output])

model.compile(optimizer='adam',
              loss={'result': 'categorical_crossentropy', 'total_goals': 'mse', 'total_corners': 'mse', 'total_cards': 'mse'},
              metrics={'result': 'accuracy', 'total_goals': 'mse', 'total_corners': 'mse', 'total_cards': 'mse'})

# %%
history = model.fit(
    [X_home_team_train, X_away_team_train, historical_stats_train],
    {'result': y_result_train, 'total_goals': y_total_goals_train, 'total_corners': y_total_corners_train, 'total_cards': y_total_cards_train},
    epochs=50,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/50
# 1322/1322 [==============================] - 8s 4ms/step - loss: 43.1154 - result_loss: 2.3502 - total_goals_loss: 6.1627 - total_corners_loss: 22.8576 - total_cards_loss: 10.5022 - result_accuracy: 0.3914 - total_goals_mse: 6.1627 - total_corners_mse: 22.8576 - total_cards_mse: 10.5022 - val_loss: 15.7014 - val_result_loss: 1.0697 - val_total_goals_loss: 2.9924 - val_total_corners_loss: 6.5849 - val_total_cards_loss: 3.9259 - val_result_accuracy: 0.4498 - val_total_goals_mse: 2.9924 - val_total_corners_mse: 6.5849 - val_total_cards_mse: 3.9259
# Epoch 2/50
# 1322/1322 [==============================] - 5s 4ms/step - loss: 18.4816 - result_loss: 1.0882 - total_goals_loss: 3.0613 - total_corners_loss: 8.9033 - total_cards_loss: 4.3479 - result_accuracy: 0.4336 - total_goals_mse: 3.0613 - total_corners_mse: 8.9033 - total_cards_mse: 4.3479 - val_loss: 9.1189 - val_result_loss: 1.0608 - val_total_goals_loss: 2.2927 - val_total_corners_loss: 2.6665 - val_total_cards_loss: 2.0700 - val_result_accuracy: 0.4506 - val_total_goals_mse: 2.2927 - val_total_corners_mse: 2.6665 - val_total_cards_mse: 2.0700
# Epoch 3/50
# 1322/1322 [==============================] - 5s 4ms/step - loss: 13.8889 - result_loss: 1.0718 - total_goals_loss: 2.3713 - total_corners_loss: 6.3730 - total_cards_loss: 3.1014 - result_accuracy: 0.4441 - total_goals_mse: 2.3713 - total_corners_mse: 6.3730 - total_cards_mse: 3.1014 - val_loss: 8.2803 - val_result_loss: 1.0568 - val_total_goals_loss: 1.5916 - val_total_corners_loss: 2.7697 - val_total_cards_loss: 1.9508 - val_result_accuracy: 0.4463 - val_total_goals_mse: 1.5916 - val_total_corners_mse: 2.7697 - val_total_cards_mse: 1.9508
# Epoch 4/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 11.5128 - result_loss: 1.0654 - total_goals_loss: 1.8253 - total_corners_loss: 5.1908 - total_cards_loss: 2.5772 - result_accuracy: 0.4464 - total_goals_mse: 1.8253 - total_corners_mse: 5.1908 - total_cards_mse: 2.5772 - val_loss: 6.1694 - val_result_loss: 1.0449 - val_total_goals_loss: 1.0080 - val_total_corners_loss: 1.9350 - val_total_cards_loss: 1.3839 - val_result_accuracy: 0.4514 - val_total_goals_mse: 1.0080 - val_total_corners_mse: 1.9350 - val_total_cards_mse: 1.3839
# Epoch 5/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 10.1383 - result_loss: 1.0615 - total_goals_loss: 1.5827 - total_corners_loss: 4.4968 - total_cards_loss: 2.2480 - result_accuracy: 0.4492 - total_goals_mse: 1.5827 - total_corners_mse: 4.4968 - total_cards_mse: 2.2480 - val_loss: 5.3917 - val_result_loss: 1.0446 - val_total_goals_loss: 0.6804 - val_total_corners_loss: 1.6186 - val_total_cards_loss: 1.3453 - val_result_accuracy: 0.4801 - val_total_goals_mse: 0.6804 - val_total_corners_mse: 1.6186 - val_total_cards_mse: 1.3453
# Epoch 6/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 9.3559 - result_loss: 1.0592 - total_goals_loss: 1.4648 - total_corners_loss: 4.0461 - total_cards_loss: 2.1236 - result_accuracy: 0.4532 - total_goals_mse: 1.4648 - total_corners_mse: 4.0461 - total_cards_mse: 2.1236 - val_loss: 5.5053 - val_result_loss: 1.0439 - val_total_goals_loss: 0.9251 - val_total_corners_loss: 1.6469 - val_total_cards_loss: 1.2556 - val_result_accuracy: 0.4546 - val_total_goals_mse: 0.9251 - val_total_corners_mse: 1.6469 - val_total_cards_mse: 1.2556
# Epoch 7/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 9.0203 - result_loss: 1.0586 - total_goals_loss: 1.4144 - total_corners_loss: 3.8857 - total_cards_loss: 2.0530 - result_accuracy: 0.4512 - total_goals_mse: 1.4144 - total_corners_mse: 3.8857 - total_cards_mse: 2.0530 - val_loss: 5.3170 - val_result_loss: 1.0403 - val_total_goals_loss: 0.7571 - val_total_corners_loss: 1.6212 - val_total_cards_loss: 1.3139 - val_result_accuracy: 0.4576 - val_total_goals_mse: 0.7571 - val_total_corners_mse: 1.6212 - val_total_cards_mse: 1.3139
# Epoch 8/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 8.5590 - result_loss: 1.0561 - total_goals_loss: 1.3391 - total_corners_loss: 3.6372 - total_cards_loss: 1.9681 - result_accuracy: 0.4525 - total_goals_mse: 1.3391 - total_corners_mse: 3.6372 - total_cards_mse: 1.9681 - val_loss: 5.4458 - val_result_loss: 1.0362 - val_total_goals_loss: 0.5966 - val_total_corners_loss: 1.9783 - val_total_cards_loss: 1.2938 - val_result_accuracy: 0.4736 - val_total_goals_mse: 0.5966 - val_total_corners_mse: 1.9783 - val_total_cards_mse: 1.2938
# Epoch 9/50
# 1322/1322 [==============================] - 5s 3ms/step - loss: 8.3436 - result_loss: 1.0578 - total_goals_loss: 1.3027 - total_corners_loss: 3.4979 - total_cards_loss: 1.9445 - result_accuracy: 0.4530 - total_goals_mse: 1.3027 - total_corners_mse: 3.4979 - total_cards_mse: 1.9445 - val_loss: 4.8281 - val_result_loss: 1.0364 - val_total_goals_loss: 0.4699 - val_total_corners_loss: 1.5996 - val_total_cards_loss: 1.1836 - val_result_accuracy: 0.4778 - val_total_goals_mse: 0.4699 - val_total_corners_mse: 1.5996 - val_total_cards_mse: 1.1836
# Epoch 10/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 8.0364 - result_loss: 1.0563 - total_goals_loss: 1.2705 - total_corners_loss: 3.3164 - total_cards_loss: 1.8637 - result_accuracy: 0.4533 - total_goals_mse: 1.2705 - total_corners_mse: 3.3164 - total_cards_mse: 1.8637 - val_loss: 5.1325 - val_result_loss: 1.0407 - val_total_goals_loss: 0.7498 - val_total_corners_loss: 1.6562 - val_total_cards_loss: 1.1583 - val_result_accuracy: 0.4752 - val_total_goals_mse: 0.7498 - val_total_corners_mse: 1.6562 - val_total_cards_mse: 1.1583
# Epoch 11/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 7.9791 - result_loss: 1.0560 - total_goals_loss: 1.2541 - total_corners_loss: 3.2720 - total_cards_loss: 1.8718 - result_accuracy: 0.4545 - total_goals_mse: 1.2541 - total_corners_mse: 3.2720 - total_cards_mse: 1.8718 - val_loss: 5.2688 - val_result_loss: 1.0398 - val_total_goals_loss: 0.6750 - val_total_corners_loss: 1.7363 - val_total_cards_loss: 1.2928 - val_result_accuracy: 0.4719 - val_total_goals_mse: 0.6750 - val_total_corners_mse: 1.7363 - val_total_cards_mse: 1.2928
# Epoch 12/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 7.8396 - result_loss: 1.0573 - total_goals_loss: 1.2612 - total_corners_loss: 3.1543 - total_cards_loss: 1.8439 - result_accuracy: 0.4537 - total_goals_mse: 1.2612 - total_corners_mse: 3.1543 - total_cards_mse: 1.8439 - val_loss: 5.3005 - val_result_loss: 1.0382 - val_total_goals_loss: 0.6219 - val_total_corners_loss: 1.8474 - val_total_cards_loss: 1.2768 - val_result_accuracy: 0.4718 - val_total_goals_mse: 0.6219 - val_total_corners_mse: 1.8474 - val_total_cards_mse: 1.2768
# Epoch 13/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 7.7171 - result_loss: 1.0549 - total_goals_loss: 1.2226 - total_corners_loss: 3.0797 - total_cards_loss: 1.8463 - result_accuracy: 0.4563 - total_goals_mse: 1.2226 - total_corners_mse: 3.0797 - total_cards_mse: 1.8463 - val_loss: 5.0141 - val_result_loss: 1.0360 - val_total_goals_loss: 0.5536 - val_total_corners_loss: 1.7679 - val_total_cards_loss: 1.1397 - val_result_accuracy: 0.4804 - val_total_goals_mse: 0.5536 - val_total_corners_mse: 1.7679 - val_total_cards_mse: 1.1397
# Epoch 14/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 7.6995 - result_loss: 1.0558 - total_goals_loss: 1.2261 - total_corners_loss: 3.0644 - total_cards_loss: 1.8389 - result_accuracy: 0.4548 - total_goals_mse: 1.2261 - total_corners_mse: 3.0644 - total_cards_mse: 1.8389 - val_loss: 4.7684 - val_result_loss: 1.0427 - val_total_goals_loss: 0.6503 - val_total_corners_loss: 1.5023 - val_total_cards_loss: 1.0557 - val_result_accuracy: 0.4646 - val_total_goals_mse: 0.6503 - val_total_corners_mse: 1.5023 - val_total_cards_mse: 1.0557
# Epoch 15/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 7.6979 - result_loss: 1.0565 - total_goals_loss: 1.2225 - total_corners_loss: 3.0615 - total_cards_loss: 1.8433 - result_accuracy: 0.4520 - total_goals_mse: 1.2225 - total_corners_mse: 3.0615 - total_cards_mse: 1.8433 - val_loss: 5.0872 - val_result_loss: 1.0383 - val_total_goals_loss: 0.5052 - val_total_corners_loss: 1.9631 - val_total_cards_loss: 1.0741 - val_result_accuracy: 0.4566 - val_total_goals_mse: 0.5052 - val_total_corners_mse: 1.9631 - val_total_cards_mse: 1.0741
# Epoch 16/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 7.5210 - result_loss: 1.0556 - total_goals_loss: 1.2161 - total_corners_loss: 2.9446 - total_cards_loss: 1.8007 - result_accuracy: 0.4533 - total_goals_mse: 1.2161 - total_corners_mse: 2.9446 - total_cards_mse: 1.8007 - val_loss: 4.6801 - val_result_loss: 1.0372 - val_total_goals_loss: 0.5369 - val_total_corners_loss: 1.6209 - val_total_cards_loss: 0.9804 - val_result_accuracy: 0.4733 - val_total_goals_mse: 0.5369 - val_total_corners_mse: 1.6209 - val_total_cards_mse: 0.9804
# Epoch 17/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 7.4634 - result_loss: 1.0571 - total_goals_loss: 1.1927 - total_corners_loss: 2.9454 - total_cards_loss: 1.7668 - result_accuracy: 0.4522 - total_goals_mse: 1.1927 - total_corners_mse: 2.9454 - total_cards_mse: 1.7668 - val_loss: 4.8882 - val_result_loss: 1.0466 - val_total_goals_loss: 0.5359 - val_total_corners_loss: 1.8219 - val_total_cards_loss: 0.9803 - val_result_accuracy: 0.4695 - val_total_goals_mse: 0.5359 - val_total_corners_mse: 1.8219 - val_total_cards_mse: 0.9803
# Epoch 18/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 7.3312 - result_loss: 1.0536 - total_goals_loss: 1.1571 - total_corners_loss: 2.8716 - total_cards_loss: 1.7451 - result_accuracy: 0.4546 - total_goals_mse: 1.1571 - total_corners_mse: 2.8716 - total_cards_mse: 1.7451 - val_loss: 4.4352 - val_result_loss: 1.0383 - val_total_goals_loss: 0.4218 - val_total_corners_loss: 1.4110 - val_total_cards_loss: 1.0624 - val_result_accuracy: 0.4621 - val_total_goals_mse: 0.4218 - val_total_corners_mse: 1.4110 - val_total_cards_mse: 1.0624
# Epoch 19/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 7.2992 - result_loss: 1.0539 - total_goals_loss: 1.1348 - total_corners_loss: 2.8808 - total_cards_loss: 1.7244 - result_accuracy: 0.4553 - total_goals_mse: 1.1348 - total_corners_mse: 2.8808 - total_cards_mse: 1.7244 - val_loss: 4.4579 - val_result_loss: 1.0351 - val_total_goals_loss: 0.3675 - val_total_corners_loss: 1.4496 - val_total_cards_loss: 1.1003 - val_result_accuracy: 0.4672 - val_total_goals_mse: 0.3675 - val_total_corners_mse: 1.4496 - val_total_cards_mse: 1.1003
# Epoch 20/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 7.2059 - result_loss: 1.0536 - total_goals_loss: 1.1271 - total_corners_loss: 2.8314 - total_cards_loss: 1.6932 - result_accuracy: 0.4561 - total_goals_mse: 1.1271 - total_corners_mse: 2.8314 - total_cards_mse: 1.6932 - val_loss: 4.6944 - val_result_loss: 1.0387 - val_total_goals_loss: 0.4618 - val_total_corners_loss: 1.7263 - val_total_cards_loss: 0.9688 - val_result_accuracy: 0.4684 - val_total_goals_mse: 0.4618 - val_total_corners_mse: 1.7263 - val_total_cards_mse: 0.9688
# Epoch 21/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 7.2177 - result_loss: 1.0530 - total_goals_loss: 1.1272 - total_corners_loss: 2.8291 - total_cards_loss: 1.7064 - result_accuracy: 0.4552 - total_goals_mse: 1.1272 - total_corners_mse: 2.8291 - total_cards_mse: 1.7064 - val_loss: 4.5193 - val_result_loss: 1.0352 - val_total_goals_loss: 0.3755 - val_total_corners_loss: 1.7165 - val_total_cards_loss: 0.8909 - val_result_accuracy: 0.4823 - val_total_goals_mse: 0.3755 - val_total_corners_mse: 1.7165 - val_total_cards_mse: 0.8909
# Epoch 22/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 7.2091 - result_loss: 1.0525 - total_goals_loss: 1.1114 - total_corners_loss: 2.8343 - total_cards_loss: 1.7095 - result_accuracy: 0.4570 - total_goals_mse: 1.1114 - total_corners_mse: 2.8343 - total_cards_mse: 1.7095 - val_loss: 4.5348 - val_result_loss: 1.0388 - val_total_goals_loss: 0.4579 - val_total_corners_loss: 1.5908 - val_total_cards_loss: 0.9439 - val_result_accuracy: 0.4676 - val_total_goals_mse: 0.4579 - val_total_corners_mse: 1.5908 - val_total_cards_mse: 0.9439
# Epoch 23/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 7.1977 - result_loss: 1.0526 - total_goals_loss: 1.1116 - total_corners_loss: 2.8413 - total_cards_loss: 1.6897 - result_accuracy: 0.4557 - total_goals_mse: 1.1116 - total_corners_mse: 2.8413 - total_cards_mse: 1.6897 - val_loss: 4.3397 - val_result_loss: 1.0376 - val_total_goals_loss: 0.3887 - val_total_corners_loss: 1.5952 - val_total_cards_loss: 0.8217 - val_result_accuracy: 0.4907 - val_total_goals_mse: 0.3887 - val_total_corners_mse: 1.5952 - val_total_cards_mse: 0.8217
# Epoch 24/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 7.1364 - result_loss: 1.0529 - total_goals_loss: 1.0936 - total_corners_loss: 2.7969 - total_cards_loss: 1.6924 - result_accuracy: 0.4556 - total_goals_mse: 1.0936 - total_corners_mse: 2.7969 - total_cards_mse: 1.6924 - val_loss: 4.8138 - val_result_loss: 1.0353 - val_total_goals_loss: 0.5224 - val_total_corners_loss: 1.7797 - val_total_cards_loss: 0.9720 - val_result_accuracy: 0.5017 - val_total_goals_mse: 0.5224 - val_total_corners_mse: 1.7797 - val_total_cards_mse: 0.9720
# Epoch 25/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 7.0659 - result_loss: 1.0521 - total_goals_loss: 1.0958 - total_corners_loss: 2.7376 - total_cards_loss: 1.6821 - result_accuracy: 0.4549 - total_goals_mse: 1.0958 - total_corners_mse: 2.7376 - total_cards_mse: 1.6821 - val_loss: 4.2927 - val_result_loss: 1.0382 - val_total_goals_loss: 0.4057 - val_total_corners_loss: 1.3890 - val_total_cards_loss: 0.9638 - val_result_accuracy: 0.4776 - val_total_goals_mse: 0.4057 - val_total_corners_mse: 1.3890 - val_total_cards_mse: 0.9638
# Epoch 26/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 7.0527 - result_loss: 1.0523 - total_goals_loss: 1.1001 - total_corners_loss: 2.7453 - total_cards_loss: 1.6572 - result_accuracy: 0.4568 - total_goals_mse: 1.1001 - total_corners_mse: 2.7453 - total_cards_mse: 1.6572 - val_loss: 4.9591 - val_result_loss: 1.0348 - val_total_goals_loss: 0.4763 - val_total_corners_loss: 2.1049 - val_total_cards_loss: 0.8417 - val_result_accuracy: 0.4886 - val_total_goals_mse: 0.4763 - val_total_corners_mse: 2.1049 - val_total_cards_mse: 0.8417
# Epoch 27/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 7.0674 - result_loss: 1.0518 - total_goals_loss: 1.0763 - total_corners_loss: 2.7423 - total_cards_loss: 1.6946 - result_accuracy: 0.4546 - total_goals_mse: 1.0763 - total_corners_mse: 2.7423 - total_cards_mse: 1.6946 - val_loss: 4.6118 - val_result_loss: 1.0332 - val_total_goals_loss: 0.3345 - val_total_corners_loss: 1.6620 - val_total_cards_loss: 1.0825 - val_result_accuracy: 0.4707 - val_total_goals_mse: 0.3345 - val_total_corners_mse: 1.6620 - val_total_cards_mse: 1.0825
# Epoch 28/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 7.0427 - result_loss: 1.0509 - total_goals_loss: 1.0785 - total_corners_loss: 2.7616 - total_cards_loss: 1.6514 - result_accuracy: 0.4568 - total_goals_mse: 1.0785 - total_corners_mse: 2.7616 - total_cards_mse: 1.6514 - val_loss: 4.5407 - val_result_loss: 1.0354 - val_total_goals_loss: 0.5444 - val_total_corners_loss: 1.6317 - val_total_cards_loss: 0.8239 - val_result_accuracy: 0.4684 - val_total_goals_mse: 0.5444 - val_total_corners_mse: 1.6317 - val_total_cards_mse: 0.8239
# Epoch 29/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 7.1226 - result_loss: 1.0505 - total_goals_loss: 1.0868 - total_corners_loss: 2.7879 - total_cards_loss: 1.6943 - result_accuracy: 0.4572 - total_goals_mse: 1.0868 - total_corners_mse: 2.7879 - total_cards_mse: 1.6943 - val_loss: 4.8037 - val_result_loss: 1.0322 - val_total_goals_loss: 0.4931 - val_total_corners_loss: 1.7478 - val_total_cards_loss: 1.0275 - val_result_accuracy: 0.4769 - val_total_goals_mse: 0.4931 - val_total_corners_mse: 1.7478 - val_total_cards_mse: 1.0275
# Epoch 30/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 7.0545 - result_loss: 1.0491 - total_goals_loss: 1.0341 - total_corners_loss: 2.7975 - total_cards_loss: 1.6773 - result_accuracy: 0.4569 - total_goals_mse: 1.0341 - total_corners_mse: 2.7975 - total_cards_mse: 1.6773 - val_loss: 4.7094 - val_result_loss: 1.0305 - val_total_goals_loss: 0.3161 - val_total_corners_loss: 1.8706 - val_total_cards_loss: 0.9962 - val_result_accuracy: 0.5113 - val_total_goals_mse: 0.3161 - val_total_corners_mse: 1.8706 - val_total_cards_mse: 0.9962
# Epoch 31/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 6.9900 - result_loss: 1.0479 - total_goals_loss: 1.0297 - total_corners_loss: 2.7491 - total_cards_loss: 1.6664 - result_accuracy: 0.4579 - total_goals_mse: 1.0297 - total_corners_mse: 2.7491 - total_cards_mse: 1.6664 - val_loss: 4.5909 - val_result_loss: 1.0250 - val_total_goals_loss: 0.3351 - val_total_corners_loss: 1.6661 - val_total_cards_loss: 1.0750 - val_result_accuracy: 0.5021 - val_total_goals_mse: 0.3351 - val_total_corners_mse: 1.6661 - val_total_cards_mse: 1.0750
# Epoch 32/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 6.9939 - result_loss: 1.0473 - total_goals_loss: 1.0344 - total_corners_loss: 2.7559 - total_cards_loss: 1.6610 - result_accuracy: 0.4574 - total_goals_mse: 1.0344 - total_corners_mse: 2.7559 - total_cards_mse: 1.6610 - val_loss: 4.5523 - val_result_loss: 1.0223 - val_total_goals_loss: 0.1905 - val_total_corners_loss: 1.8312 - val_total_cards_loss: 1.0087 - val_result_accuracy: 0.4493 - val_total_goals_mse: 0.1905 - val_total_corners_mse: 1.8312 - val_total_cards_mse: 1.0087
# Epoch 33/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 6.8844 - result_loss: 1.0452 - total_goals_loss: 1.0050 - total_corners_loss: 2.6840 - total_cards_loss: 1.6510 - result_accuracy: 0.4571 - total_goals_mse: 1.0050 - total_corners_mse: 2.6840 - total_cards_mse: 1.6510 - val_loss: 4.7753 - val_result_loss: 1.0210 - val_total_goals_loss: 0.2890 - val_total_corners_loss: 1.8638 - val_total_cards_loss: 1.0948 - val_result_accuracy: 0.4906 - val_total_goals_mse: 0.2890 - val_total_corners_mse: 1.8638 - val_total_cards_mse: 1.0948
# Epoch 34/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 6.8784 - result_loss: 1.0459 - total_goals_loss: 0.9900 - total_corners_loss: 2.6915 - total_cards_loss: 1.6532 - result_accuracy: 0.4588 - total_goals_mse: 0.9900 - total_corners_mse: 2.6915 - total_cards_mse: 1.6532 - val_loss: 4.5405 - val_result_loss: 1.0213 - val_total_goals_loss: 0.3380 - val_total_corners_loss: 1.6801 - val_total_cards_loss: 1.0098 - val_result_accuracy: 0.5221 - val_total_goals_mse: 0.3380 - val_total_corners_mse: 1.6801 - val_total_cards_mse: 1.0098
# Epoch 35/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 6.9658 - result_loss: 1.0417 - total_goals_loss: 0.9855 - total_corners_loss: 2.7930 - total_cards_loss: 1.6496 - result_accuracy: 0.4598 - total_goals_mse: 0.9855 - total_corners_mse: 2.7930 - total_cards_mse: 1.6496 - val_loss: 4.4757 - val_result_loss: 1.0191 - val_total_goals_loss: 0.2067 - val_total_corners_loss: 1.7121 - val_total_cards_loss: 1.0418 - val_result_accuracy: 0.4963 - val_total_goals_mse: 0.2067 - val_total_corners_mse: 1.7121 - val_total_cards_mse: 1.0418
# Epoch 36/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 6.9435 - result_loss: 1.0423 - total_goals_loss: 0.9968 - total_corners_loss: 2.7337 - total_cards_loss: 1.6712 - result_accuracy: 0.4603 - total_goals_mse: 0.9968 - total_corners_mse: 2.7337 - total_cards_mse: 1.6712 - val_loss: 4.1523 - val_result_loss: 1.0211 - val_total_goals_loss: 0.2394 - val_total_corners_loss: 1.3859 - val_total_cards_loss: 1.0042 - val_result_accuracy: 0.4940 - val_total_goals_mse: 0.2394 - val_total_corners_mse: 1.3859 - val_total_cards_mse: 1.0042
# Epoch 37/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 6.9220 - result_loss: 1.0432 - total_goals_loss: 0.9957 - total_corners_loss: 2.7558 - total_cards_loss: 1.6291 - result_accuracy: 0.4592 - total_goals_mse: 0.9957 - total_corners_mse: 2.7558 - total_cards_mse: 1.6291 - val_loss: 4.3722 - val_result_loss: 1.0194 - val_total_goals_loss: 0.2318 - val_total_corners_loss: 1.6621 - val_total_cards_loss: 0.9558 - val_result_accuracy: 0.5109 - val_total_goals_mse: 0.2318 - val_total_corners_mse: 1.6621 - val_total_cards_mse: 0.9558
# Epoch 38/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 6.9178 - result_loss: 1.0463 - total_goals_loss: 0.9982 - total_corners_loss: 2.7454 - total_cards_loss: 1.6266 - result_accuracy: 0.4553 - total_goals_mse: 0.9982 - total_corners_mse: 2.7454 - total_cards_mse: 1.6266 - val_loss: 4.6580 - val_result_loss: 1.0234 - val_total_goals_loss: 0.2556 - val_total_corners_loss: 1.5097 - val_total_cards_loss: 1.3593 - val_result_accuracy: 0.4668 - val_total_goals_mse: 0.2556 - val_total_corners_mse: 1.5097 - val_total_cards_mse: 1.3593
# Epoch 39/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 6.9306 - result_loss: 1.0451 - total_goals_loss: 0.9878 - total_corners_loss: 2.6933 - total_cards_loss: 1.7000 - result_accuracy: 0.4573 - total_goals_mse: 0.9878 - total_corners_mse: 2.6933 - total_cards_mse: 1.7000 - val_loss: 4.3204 - val_result_loss: 1.0246 - val_total_goals_loss: 0.3200 - val_total_corners_loss: 1.5459 - val_total_cards_loss: 0.9297 - val_result_accuracy: 0.5140 - val_total_goals_mse: 0.3200 - val_total_corners_mse: 1.5459 - val_total_cards_mse: 0.9297
# Epoch 40/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 6.8784 - result_loss: 1.0436 - total_goals_loss: 0.9850 - total_corners_loss: 2.6827 - total_cards_loss: 1.6698 - result_accuracy: 0.4596 - total_goals_mse: 0.9850 - total_corners_mse: 2.6827 - total_cards_mse: 1.6698 - val_loss: 4.2798 - val_result_loss: 1.0255 - val_total_goals_loss: 0.2316 - val_total_corners_loss: 1.6193 - val_total_cards_loss: 0.9104 - val_result_accuracy: 0.4685 - val_total_goals_mse: 0.2316 - val_total_corners_mse: 1.6193 - val_total_cards_mse: 0.9104
# Epoch 41/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 6.8379 - result_loss: 1.0426 - total_goals_loss: 0.9714 - total_corners_loss: 2.6845 - total_cards_loss: 1.6409 - result_accuracy: 0.4586 - total_goals_mse: 0.9714 - total_corners_mse: 2.6845 - total_cards_mse: 1.6409 - val_loss: 4.5040 - val_result_loss: 1.0214 - val_total_goals_loss: 0.3024 - val_total_corners_loss: 1.7701 - val_total_cards_loss: 0.9164 - val_result_accuracy: 0.5084 - val_total_goals_mse: 0.3024 - val_total_corners_mse: 1.7701 - val_total_cards_mse: 0.9164
# Epoch 42/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 6.8847 - result_loss: 1.0430 - total_goals_loss: 0.9611 - total_corners_loss: 2.7599 - total_cards_loss: 1.6281 - result_accuracy: 0.4585 - total_goals_mse: 0.9611 - total_corners_mse: 2.7599 - total_cards_mse: 1.6281 - val_loss: 4.6277 - val_result_loss: 1.0291 - val_total_goals_loss: 0.5120 - val_total_corners_loss: 1.6547 - val_total_cards_loss: 0.9368 - val_result_accuracy: 0.5091 - val_total_goals_mse: 0.5120 - val_total_corners_mse: 1.6547 - val_total_cards_mse: 0.9368
# Epoch 43/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 6.8590 - result_loss: 1.0428 - total_goals_loss: 0.9717 - total_corners_loss: 2.7238 - total_cards_loss: 1.6248 - result_accuracy: 0.4578 - total_goals_mse: 0.9717 - total_corners_mse: 2.7238 - total_cards_mse: 1.6248 - val_loss: 4.4042 - val_result_loss: 1.0204 - val_total_goals_loss: 0.2646 - val_total_corners_loss: 1.6567 - val_total_cards_loss: 0.9650 - val_result_accuracy: 0.4919 - val_total_goals_mse: 0.2646 - val_total_corners_mse: 1.6567 - val_total_cards_mse: 0.9650
# Epoch 44/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 6.8582 - result_loss: 1.0416 - total_goals_loss: 0.9717 - total_corners_loss: 2.7395 - total_cards_loss: 1.6068 - result_accuracy: 0.4581 - total_goals_mse: 0.9717 - total_corners_mse: 2.7395 - total_cards_mse: 1.6068 - val_loss: 4.4507 - val_result_loss: 1.0146 - val_total_goals_loss: 0.3015 - val_total_corners_loss: 1.6035 - val_total_cards_loss: 1.0236 - val_result_accuracy: 0.5234 - val_total_goals_mse: 0.3015 - val_total_corners_mse: 1.6035 - val_total_cards_mse: 1.0236
# Epoch 45/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 6.9349 - result_loss: 1.0433 - total_goals_loss: 0.9562 - total_corners_loss: 2.7755 - total_cards_loss: 1.6508 - result_accuracy: 0.4577 - total_goals_mse: 0.9562 - total_corners_mse: 2.7755 - total_cards_mse: 1.6508 - val_loss: 4.1102 - val_result_loss: 1.0179 - val_total_goals_loss: 0.2873 - val_total_corners_loss: 1.3394 - val_total_cards_loss: 0.9585 - val_result_accuracy: 0.4999 - val_total_goals_mse: 0.2873 - val_total_corners_mse: 1.3394 - val_total_cards_mse: 0.9585
# Epoch 46/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 6.8578 - result_loss: 1.0399 - total_goals_loss: 0.9541 - total_corners_loss: 2.7141 - total_cards_loss: 1.6440 - result_accuracy: 0.4607 - total_goals_mse: 0.9541 - total_corners_mse: 2.7141 - total_cards_mse: 1.6440 - val_loss: 4.5750 - val_result_loss: 1.0164 - val_total_goals_loss: 0.2683 - val_total_corners_loss: 1.7079 - val_total_cards_loss: 1.0779 - val_result_accuracy: 0.4970 - val_total_goals_mse: 0.2683 - val_total_corners_mse: 1.7079 - val_total_cards_mse: 1.0779
# Epoch 47/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 6.8656 - result_loss: 1.0421 - total_goals_loss: 0.9642 - total_corners_loss: 2.7100 - total_cards_loss: 1.6439 - result_accuracy: 0.4595 - total_goals_mse: 0.9642 - total_corners_mse: 2.7100 - total_cards_mse: 1.6439 - val_loss: 4.4827 - val_result_loss: 1.0210 - val_total_goals_loss: 0.2067 - val_total_corners_loss: 1.8276 - val_total_cards_loss: 0.9134 - val_result_accuracy: 0.5021 - val_total_goals_mse: 0.2067 - val_total_corners_mse: 1.8276 - val_total_cards_mse: 0.9134
# Epoch 48/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 6.8089 - result_loss: 1.0403 - total_goals_loss: 0.9509 - total_corners_loss: 2.6855 - total_cards_loss: 1.6204 - result_accuracy: 0.4616 - total_goals_mse: 0.9509 - total_corners_mse: 2.6855 - total_cards_mse: 1.6204 - val_loss: 4.4828 - val_result_loss: 1.0238 - val_total_goals_loss: 0.2127 - val_total_corners_loss: 1.7400 - val_total_cards_loss: 0.9980 - val_result_accuracy: 0.5175 - val_total_goals_mse: 0.2127 - val_total_corners_mse: 1.7400 - val_total_cards_mse: 0.9980
# Epoch 49/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 6.8146 - result_loss: 1.0425 - total_goals_loss: 0.9584 - total_corners_loss: 2.6735 - total_cards_loss: 1.6301 - result_accuracy: 0.4593 - total_goals_mse: 0.9584 - total_corners_mse: 2.6735 - total_cards_mse: 1.6301 - val_loss: 4.8406 - val_result_loss: 1.0250 - val_total_goals_loss: 0.2934 - val_total_corners_loss: 2.0067 - val_total_cards_loss: 1.0046 - val_result_accuracy: 0.5122 - val_total_goals_mse: 0.2934 - val_total_corners_mse: 2.0067 - val_total_cards_mse: 1.0046
# Epoch 50/50
# 1322/1322 [==============================] - 4s 3ms/step - loss: 6.8434 - result_loss: 1.0411 - total_goals_loss: 0.9527 - total_corners_loss: 2.7290 - total_cards_loss: 1.6144 - result_accuracy: 0.4600 - total_goals_mse: 0.9527 - total_corners_mse: 2.7290 - total_cards_mse: 1.6144 - val_loss: 4.6325 - val_result_loss: 1.0163 - val_total_goals_loss: 0.2363 - val_total_corners_loss: 1.9146 - val_total_cards_loss: 0.9581 - val_result_accuracy: 0.4926 - val_total_goals_mse: 0.2363 - val_total_corners_mse: 1.9146 - val_total_cards_mse: 0.9581

# %% [markdown]
# # Evaluation

# %%
results = model.evaluate(
    [X_home_team_test, X_away_team_test, historical_stats_test],
    {'result': y_result_test, 'total_goals': y_total_goals_test, 'total_corners': y_total_corners_test, 'total_cards': y_total_cards_test}
)
print(results)
# Out:
# 413/413 [==============================] - 1s 2ms/step - loss: 4.6770 - result_loss: 1.0353 - total_goals_loss: 0.6013 - total_corners_loss: 1.2155 - total_cards_loss: 1.3113 - result_accuracy: 0.4543 - total_goals_mse: 0.6013 - total_corners_mse: 1.2155 - total_cards_mse: 1.3113
# [4.676986217498779, 1.035331130027771, 0.6013466715812683, 1.2155369520187378, 1.311293601989746, 0.454297810792923, 0.6013466715812683, 1.2155369520187378, 1.311293601989746]

# %%
def visualize_training(history):
    plt.figure(figsize=(20, 15))

    # Accuracy dla wyniku
    plt.subplot(3, 3, 1)
    plt.plot(history.history['result_accuracy'])
    plt.plot(history.history['val_result_accuracy'])
    plt.title('Model accuracy (result)')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Loss dla wyniku
    plt.subplot(3, 3, 2)
    plt.plot(history.history['result_loss'])
    plt.plot(history.history['val_result_loss'])
    plt.title('Model loss (result)')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # MSE dla liczby goli
    plt.subplot(3, 3, 3)
    plt.plot(history.history['total_goals_mse'])
    plt.plot(history.history['val_total_goals_mse'])
    plt.title('Model MSE (total goals)')
    plt.ylabel('MSE')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Loss dla liczby goli
    plt.subplot(3, 3, 4)
    plt.plot(history.history['total_goals_loss'])
    plt.plot(history.history['val_total_goals_loss'])
    plt.title('Model loss (total goals)')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # MSE dla liczby rzutów rożnych
    plt.subplot(3, 3, 5)
    plt.plot(history.history['total_corners_mse'])
    plt.plot(history.history['val_total_corners_mse'])
    plt.title('Model MSE (total corners)')
    plt.ylabel('MSE')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Loss dla liczby rzutów rożnych
    plt.subplot(3, 3, 6)
    plt.plot(history.history['total_corners_loss'])
    plt.plot(history.history['val_total_corners_loss'])
    plt.title('Model loss (total corners)')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # MSE dla liczby kartek
    plt.subplot(3, 3, 7)
    plt.plot(history.history['total_cards_mse'])
    plt.plot(history.history['val_total_cards_mse'])
    plt.title('Model MSE (total cards)')
    plt.ylabel('MSE')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Loss dla liczby kartek
    plt.subplot(3, 3, 8)
    plt.plot(history.history['total_cards_loss'])
    plt.plot(history.history['val_total_cards_loss'])
    plt.title('Model loss (total cards)')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # General loss
    plt.subplot(3, 3, 9)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('General model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.tight_layout()
    plt.show()

# Wywołanie funkcji visualize_training
visualize_training(history)

# %% [markdown]
# # Predictions

# %%
def predict_match(model, home_team, away_team, le, input_shape_stats):
    home_team_encoded = le.transform([home_team])
    away_team_encoded = le.transform([away_team])

    historical_stats_array = np.zeros((1, input_shape_stats))  # Zero array for historical stats

    predictions = model.predict([home_team_encoded, away_team_encoded, historical_stats_array])
    
    result = np.argmax(predictions[0], axis=1)[0]
    total_goals = int(np.round(predictions[1][0][0]))
    total_corners = int(np.round(predictions[2][0][0]))
    total_cards = int(np.round(predictions[3][0][0]))

    return {'result': result, 'total_goals': max(0, total_goals), 'total_corners': max(0, total_corners), 'total_cards': max(0, total_cards)}

# Przykładowa predykcja
prediction = predict_match(model, 'Manchester United', 'Manchester City', le, input_shape_stats)
print(prediction)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# {'result': 0, 'total_goals': 0, 'total_corners': 0, 'total_cards': 1}

# %% [markdown]
# # LSTM

# %% [markdown]
# ## Data preprocessing

# %%
le = LabelEncoder()

# %%
#fit transform na jednym zbiorze i zwykły transform na drugim aby uniknąć podwójnego enkodowania
data['home_team_encoded'] = le.fit_transform(data['home_team_name'])
data['away_team_encoded'] = le.transform(data['away_team_name'])

# %%
all_teams = list(set(np.concatenate((data['home_team_name'], data['away_team_name']))))

# %%
le.fit(all_teams)
# Out:
# LabelEncoder()

# %%
data['home_team_encoded'] = le.transform(data['home_team_name'])
data['away_team_encoded'] = le.transform(data['away_team_name'])

# %%
features = ['home_team_encoded', 'away_team_encoded', 'Pre-Match PPG (Home)', 'Pre-Match PPG (Away)', 'home_ppg', 
            'away_ppg', 'home_team_goal_count', 'away_team_goal_count', 'total_goal_count', 'total_goals_at_half_time', 
            'home_team_goal_count_half_time', 'away_team_goal_count_half_time', 'home_team_corner_count', 
            'away_team_corner_count', 'home_team_yellow_cards', 'home_team_red_cards', 'away_team_yellow_cards', 
            'away_team_red_cards', 'home_team_first_half_cards', 'home_team_second_half_cards', 
            'away_team_first_half_cards', 'away_team_second_half_cards', 'home_team_shots', 'away_team_shots', 
            'home_team_shots_on_target', 'away_team_shots_on_target', 'home_team_shots_off_target', 
            'away_team_shots_off_target', 'home_team_fouls', 'away_team_fouls', 'home_team_possession', 
            'away_team_possession', 'Home Team Pre-Match xG', 'Away Team Pre-Match xG', 'team_a_xg', 'team_b_xg', 
            'average_goals_per_match_pre_match', 'btts_percentage_pre_match', 'over_15_percentage_pre_match', 
            'over_25_percentage_pre_match', 'over_35_percentage_pre_match', 'over_45_percentage_pre_match', 
            'over_15_HT_FHG_percentage_pre_match', 'over_05_HT_FHG_percentage_pre_match', 'over_15_2HG_percentage_pre_match', 
            'over_05_2HG_percentage_pre_match', 'average_corners_per_match_pre_match', 'average_cards_per_match_pre_match', 
            'odds_ft_home_team_win', 'odds_ft_draw', 'odds_ft_away_team_win', 'odds_ft_over15', 'odds_ft_over25', 
            'odds_ft_over35', 'odds_ft_over45', 'odds_btts_yes', 'odds_btts_no']

# %%
# 5. Przygotowanie danych
X = data[features].values
y_result = data['result'].values
y_total_goals = data['total_goal_count'].values
y_total_corners = data['corners_total'].values
y_total_cards = data['cards_total'].values

# %%
# Podział danych na zestawy treningowe i testowe
X_train, X_test, y_result_train, y_result_test, y_total_goals_train, y_total_goals_test, y_total_corners_train, y_total_corners_test, y_total_cards_train, y_total_cards_test = train_test_split(
    X, y_result, y_total_goals, y_total_corners, y_total_cards, test_size=0.2, random_state=42)

# %%
# Sekwencje danych
sequence_length = 10

def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequences.append(data[i:i + seq_length])
    return np.array(sequences)

# %%
X_home_team_train_seq = create_sequences(X_train[:, 0], sequence_length)

# %%
X_home_team_train_seq = create_sequences(X_train[:, 0], sequence_length)
X_away_team_train_seq = create_sequences(X_train[:, 1], sequence_length)
historical_stats_train_seq = create_sequences(X_train[:, 2:], sequence_length)

y_result_train_seq = create_sequences(y_result_train, sequence_length)
y_total_goals_train_seq = create_sequences(y_total_goals_train, sequence_length)
y_total_corners_train_seq = create_sequences(y_total_corners_train, sequence_length)
y_total_cards_train_seq = create_sequences(y_total_cards_train, sequence_length)

X_home_team_test_seq = create_sequences(X_test[:, 0], sequence_length)
X_away_team_test_seq = create_sequences(X_test[:, 1], sequence_length)
historical_stats_test_seq = create_sequences(X_test[:, 2:], sequence_length)

y_result_test_seq = create_sequences(y_result_test, sequence_length)
y_total_goals_test_seq = create_sequences(y_total_goals_test, sequence_length)
y_total_corners_test_seq = create_sequences(y_total_corners_test, sequence_length)
y_total_cards_test_seq = create_sequences(y_total_cards_test, sequence_length)

# %% [markdown]
# ## Model

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten, Embedding, concatenate, LSTM, Dropout
from tensorflow.keras.optimizers import Adam

# 6. Tworzenie modelu LSTM
num_teams = len(le.classes_)
input_shape_stats = historical_stats_train_seq.shape[2]

# Wejścia
home_team_input = Input(shape=(sequence_length,))
away_team_input = Input(shape=(sequence_length,))
stats_input = Input(shape=(sequence_length, input_shape_stats))

# Embedding dla drużyn
home_team_embedding = Embedding(input_dim=num_teams, output_dim=32)(home_team_input)
away_team_embedding = Embedding(input_dim=num_teams, output_dim=32)(away_team_input)

# LSTM dla sekwencji wyników drużyn
home_team_lstm = LSTM(32, return_sequences=False)(home_team_embedding)
away_team_lstm = LSTM(32, return_sequences=False)(away_team_embedding)

# LSTM dla historycznych statystyk
stats_lstm = LSTM(64, return_sequences=False)(stats_input)

# Połączenie wszystkich wejść
merged = concatenate([home_team_lstm, away_team_lstm, stats_lstm])
merged = Dense(128, activation='relu', kernel_regularizer=l2(0.01))(merged)
merged = Dropout(0.5)(merged)
merged = Dense(64, activation='relu', kernel_regularizer=l2(0.01))(merged)
merged = Dropout(0.5)(merged)

# Warstwy wyjściowe
result_output = Dense(3, activation='softmax', name='result')(merged)
goals_output = Dense(1, activation='relu', name='total_goals')(merged)
corners_output = Dense(1, activation='relu', name='total_corners')(merged)
cards_output = Dense(1, activation='relu', name='total_cards')(merged)

# Tworzenie modelu
model = Model(inputs=[home_team_input, away_team_input, stats_input],
              outputs=[result_output, goals_output, corners_output, cards_output])

model.compile(optimizer=Adam(),
              loss={'result': 'sparse_categorical_crossentropy', 'total_goals': 'mse', 'total_corners': 'mse', 'total_cards': 'mse'},
              metrics={'result': 'accuracy', 'total_goals': 'mse', 'total_corners': 'mse', 'total_cards': 'mse'})
# Out:
# WARNING:tensorflow:From c:\ProgramData\anaconda3\envs\magisterka_env\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %% [markdown]
# ## Trening

# %%
# 7. Trening modelu
history = model.fit(
    [X_home_team_train_seq, X_away_team_train_seq, historical_stats_train_seq],
    {'result': y_result_train_seq[:, -1], 'total_goals': y_total_goals_train_seq[:, -1], 'total_corners': y_total_corners_train_seq[:, -1], 'total_cards': y_total_cards_train_seq[:, -1]},
    epochs=50,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\ProgramData\anaconda3\envs\magisterka_env\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\ProgramData\anaconda3\envs\magisterka_env\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 1322/1322 [==============================] - 18s 8ms/step - loss: 20.7909 - result_loss: 1.1857 - total_goals_loss: 3.5185 - total_corners_loss: 10.2287 - total_cards_loss: 4.7418 - result_accuracy: 0.4041 - total_goals_mse: 3.5185 - total_corners_mse: 10.2287 - total_cards_mse: 4.7418 - val_loss: 7.4240 - val_result_loss: 1.0669 - val_total_goals_loss: 2.7971 - val_total_corners_loss: 1.5456 - val_total_cards_loss: 1.1913 - val_result_accuracy: 0.4517 - val_total_goals_mse: 2.7971 - val_total_corners_mse: 1.5456 - val_total_cards_mse: 1.1913
# Epoch 2/50
# 1322/1322 [==============================] - 9s 7ms/step - loss: 10.9649 - result_loss: 1.0663 - total_goals_loss: 2.4583 - total_corners_loss: 4.5994 - total_cards_loss: 2.1122 - result_accuracy: 0.4461 - total_goals_mse: 2.4583 - total_corners_mse: 4.5994 - total_cards_mse: 2.1122 - val_loss: 5.1275 - val_result_loss: 1.0461 - val_total_goals_loss: 0.9835 - val_total_corners_loss: 1.5513 - val_total_cards_loss: 0.8729 - val_result_accuracy: 0.4449 - val_total_goals_mse: 0.9835 - val_total_corners_mse: 1.5513 - val_total_cards_mse: 0.8729
# Epoch 3/50
# 1322/1322 [==============================] - 9s 7ms/step - loss: 8.9065 - result_loss: 1.0557 - total_goals_loss: 1.3503 - total_corners_loss: 4.0029 - total_cards_loss: 1.8649 - result_accuracy: 0.4489 - total_goals_mse: 1.3503 - total_corners_mse: 4.0029 - total_cards_mse: 1.8649 - val_loss: 5.3035 - val_result_loss: 1.0433 - val_total_goals_loss: 0.9411 - val_total_corners_loss: 2.0414 - val_total_cards_loss: 0.6736 - val_result_accuracy: 0.4545 - val_total_goals_mse: 0.9411 - val_total_corners_mse: 2.0414 - val_total_cards_mse: 0.6736
# Epoch 4/50
# 1322/1322 [==============================] - 9s 7ms/step - loss: 8.0450 - result_loss: 1.0532 - total_goals_loss: 1.1089 - total_corners_loss: 3.6086 - total_cards_loss: 1.6914 - result_accuracy: 0.4513 - total_goals_mse: 1.1089 - total_corners_mse: 3.6086 - total_cards_mse: 1.6914 - val_loss: 3.9584 - val_result_loss: 1.0389 - val_total_goals_loss: 0.5629 - val_total_corners_loss: 1.0810 - val_total_cards_loss: 0.7181 - val_result_accuracy: 0.4519 - val_total_goals_mse: 0.5629 - val_total_corners_mse: 1.0810 - val_total_cards_mse: 0.7181
# Epoch 5/50
# 1322/1322 [==============================] - 12s 9ms/step - loss: 7.4676 - result_loss: 1.0511 - total_goals_loss: 0.9709 - total_corners_loss: 3.3286 - total_cards_loss: 1.5658 - result_accuracy: 0.4539 - total_goals_mse: 0.9709 - total_corners_mse: 3.3286 - total_cards_mse: 1.5658 - val_loss: 3.7731 - val_result_loss: 1.0369 - val_total_goals_loss: 0.4284 - val_total_corners_loss: 1.1205 - val_total_cards_loss: 0.6485 - val_result_accuracy: 0.4732 - val_total_goals_mse: 0.4284 - val_total_corners_mse: 1.1205 - val_total_cards_mse: 0.6485
# Epoch 6/50
# 1322/1322 [==============================] - 11s 9ms/step - loss: 7.0345 - result_loss: 1.0499 - total_goals_loss: 0.8873 - total_corners_loss: 3.0756 - total_cards_loss: 1.4903 - result_accuracy: 0.4566 - total_goals_mse: 0.8873 - total_corners_mse: 3.0756 - total_cards_mse: 1.4903 - val_loss: 3.6145 - val_result_loss: 1.0385 - val_total_goals_loss: 0.2799 - val_total_corners_loss: 1.3316 - val_total_cards_loss: 0.4464 - val_result_accuracy: 0.4719 - val_total_goals_mse: 0.2799 - val_total_corners_mse: 1.3316 - val_total_cards_mse: 0.4464
# Epoch 7/50
# 1322/1322 [==============================] - 13s 10ms/step - loss: 6.7588 - result_loss: 1.0494 - total_goals_loss: 0.8415 - total_corners_loss: 2.9201 - total_cards_loss: 1.4334 - result_accuracy: 0.4563 - total_goals_mse: 0.8415 - total_corners_mse: 2.9201 - total_cards_mse: 1.4334 - val_loss: 3.4819 - val_result_loss: 1.0386 - val_total_goals_loss: 0.3108 - val_total_corners_loss: 1.2154 - val_total_cards_loss: 0.4132 - val_result_accuracy: 0.4519 - val_total_goals_mse: 0.3108 - val_total_corners_mse: 1.2154 - val_total_cards_mse: 0.4132
# Epoch 8/50
# 1322/1322 [==============================] - 15s 11ms/step - loss: 6.4793 - result_loss: 1.0481 - total_goals_loss: 0.8050 - total_corners_loss: 2.7478 - total_cards_loss: 1.3821 - result_accuracy: 0.4598 - total_goals_mse: 0.8050 - total_corners_mse: 2.7478 - total_cards_mse: 1.3821 - val_loss: 3.6878 - val_result_loss: 1.0373 - val_total_goals_loss: 0.3570 - val_total_corners_loss: 1.2278 - val_total_cards_loss: 0.5810 - val_result_accuracy: 0.4653 - val_total_goals_mse: 0.3570 - val_total_corners_mse: 1.2278 - val_total_cards_mse: 0.5810
# Epoch 9/50
# 1322/1322 [==============================] - 12s 9ms/step - loss: 6.3025 - result_loss: 1.0477 - total_goals_loss: 0.7639 - total_corners_loss: 2.6865 - total_cards_loss: 1.3256 - result_accuracy: 0.4612 - total_goals_mse: 0.7639 - total_corners_mse: 2.6865 - total_cards_mse: 1.3256 - val_loss: 3.5733 - val_result_loss: 1.0393 - val_total_goals_loss: 0.2632 - val_total_corners_loss: 1.3997 - val_total_cards_loss: 0.3990 - val_result_accuracy: 0.4751 - val_total_goals_mse: 0.2632 - val_total_corners_mse: 1.3997 - val_total_cards_mse: 0.3990
# Epoch 10/50
# 1322/1322 [==============================] - 11s 8ms/step - loss: 6.2071 - result_loss: 1.0468 - total_goals_loss: 0.7680 - total_corners_loss: 2.6144 - total_cards_loss: 1.3065 - result_accuracy: 0.4617 - total_goals_mse: 0.7680 - total_corners_mse: 2.6144 - total_cards_mse: 1.3065 - val_loss: 3.3798 - val_result_loss: 1.0357 - val_total_goals_loss: 0.2973 - val_total_corners_loss: 1.1441 - val_total_cards_loss: 0.4364 - val_result_accuracy: 0.4829 - val_total_goals_mse: 0.2973 - val_total_corners_mse: 1.1441 - val_total_cards_mse: 0.4364
# Epoch 11/50
# 1322/1322 [==============================] - 12s 9ms/step - loss: 6.0265 - result_loss: 1.0463 - total_goals_loss: 0.7435 - total_corners_loss: 2.5042 - total_cards_loss: 1.2712 - result_accuracy: 0.4615 - total_goals_mse: 0.7435 - total_corners_mse: 2.5042 - total_cards_mse: 1.2712 - val_loss: 3.3915 - val_result_loss: 1.0343 - val_total_goals_loss: 0.2182 - val_total_corners_loss: 1.2432 - val_total_cards_loss: 0.4461 - val_result_accuracy: 0.4954 - val_total_goals_mse: 0.2182 - val_total_corners_mse: 1.2432 - val_total_cards_mse: 0.4461
# Epoch 12/50
# 1322/1322 [==============================] - 11s 8ms/step - loss: 5.8387 - result_loss: 1.0450 - total_goals_loss: 0.7156 - total_corners_loss: 2.4020 - total_cards_loss: 1.2260 - result_accuracy: 0.4619 - total_goals_mse: 0.7156 - total_corners_mse: 2.4020 - total_cards_mse: 1.2260 - val_loss: 3.4411 - val_result_loss: 1.0343 - val_total_goals_loss: 0.2429 - val_total_corners_loss: 1.1825 - val_total_cards_loss: 0.5339 - val_result_accuracy: 0.4888 - val_total_goals_mse: 0.2429 - val_total_corners_mse: 1.1825 - val_total_cards_mse: 0.5339
# Epoch 13/50
# 1322/1322 [==============================] - 11s 9ms/step - loss: 5.7095 - result_loss: 1.0440 - total_goals_loss: 0.6921 - total_corners_loss: 2.3399 - total_cards_loss: 1.1918 - result_accuracy: 0.4623 - total_goals_mse: 0.6921 - total_corners_mse: 2.3399 - total_cards_mse: 1.1918 - val_loss: 3.1209 - val_result_loss: 1.0318 - val_total_goals_loss: 0.2224 - val_total_corners_loss: 1.0384 - val_total_cards_loss: 0.3898 - val_result_accuracy: 0.4586 - val_total_goals_mse: 0.2224 - val_total_corners_mse: 1.0384 - val_total_cards_mse: 0.3898
# Epoch 14/50
# 1322/1322 [==============================] - 9s 7ms/step - loss: 5.6472 - result_loss: 1.0429 - total_goals_loss: 0.6778 - total_corners_loss: 2.3089 - total_cards_loss: 1.1779 - result_accuracy: 0.4628 - total_goals_mse: 0.6778 - total_corners_mse: 2.3089 - total_cards_mse: 1.1779 - val_loss: 3.0593 - val_result_loss: 1.0302 - val_total_goals_loss: 0.2096 - val_total_corners_loss: 1.0404 - val_total_cards_loss: 0.3428 - val_result_accuracy: 0.4868 - val_total_goals_mse: 0.2096 - val_total_corners_mse: 1.0404 - val_total_cards_mse: 0.3428
# Epoch 15/50
# 1322/1322 [==============================] - 10s 8ms/step - loss: 5.5553 - result_loss: 1.0425 - total_goals_loss: 0.6619 - total_corners_loss: 2.2742 - total_cards_loss: 1.1446 - result_accuracy: 0.4635 - total_goals_mse: 0.6619 - total_corners_mse: 2.2742 - total_cards_mse: 1.1446 - val_loss: 3.1060 - val_result_loss: 1.0314 - val_total_goals_loss: 0.1575 - val_total_corners_loss: 1.0700 - val_total_cards_loss: 0.4208 - val_result_accuracy: 0.4902 - val_total_goals_mse: 0.1575 - val_total_corners_mse: 1.0700 - val_total_cards_mse: 0.4208
# Epoch 16/50
# 1322/1322 [==============================] - 10s 8ms/step - loss: 5.5110 - result_loss: 1.0409 - total_goals_loss: 0.6438 - total_corners_loss: 2.2756 - total_cards_loss: 1.1274 - result_accuracy: 0.4668 - total_goals_mse: 0.6438 - total_corners_mse: 2.2756 - total_cards_mse: 1.1274 - val_loss: 3.4908 - val_result_loss: 1.0303 - val_total_goals_loss: 0.2752 - val_total_corners_loss: 1.2348 - val_total_cards_loss: 0.5316 - val_result_accuracy: 0.4862 - val_total_goals_mse: 0.2752 - val_total_corners_mse: 1.2348 - val_total_cards_mse: 0.5316
# Epoch 17/50
# 1322/1322 [==============================] - 10s 7ms/step - loss: 5.4140 - result_loss: 1.0404 - total_goals_loss: 0.6524 - total_corners_loss: 2.1974 - total_cards_loss: 1.1103 - result_accuracy: 0.4669 - total_goals_mse: 0.6524 - total_corners_mse: 2.1974 - total_cards_mse: 1.1103 - val_loss: 3.3442 - val_result_loss: 1.0285 - val_total_goals_loss: 0.1900 - val_total_corners_loss: 1.2469 - val_total_cards_loss: 0.4666 - val_result_accuracy: 0.4827 - val_total_goals_mse: 0.1900 - val_total_corners_mse: 1.2469 - val_total_cards_mse: 0.4666
# Epoch 18/50
# 1322/1322 [==============================] - 9s 7ms/step - loss: 5.3271 - result_loss: 1.0391 - total_goals_loss: 0.6312 - total_corners_loss: 2.1693 - total_cards_loss: 1.0821 - result_accuracy: 0.4665 - total_goals_mse: 0.6312 - total_corners_mse: 2.1693 - total_cards_mse: 1.0821 - val_loss: 2.8362 - val_result_loss: 1.0251 - val_total_goals_loss: 0.1147 - val_total_corners_loss: 0.9927 - val_total_cards_loss: 0.3030 - val_result_accuracy: 0.5066 - val_total_goals_mse: 0.1147 - val_total_corners_mse: 0.9927 - val_total_cards_mse: 0.3030
# Epoch 19/50
# 1322/1322 [==============================] - 9s 7ms/step - loss: 5.3486 - result_loss: 1.0401 - total_goals_loss: 0.6157 - total_corners_loss: 2.1919 - total_cards_loss: 1.0926 - result_accuracy: 0.4668 - total_goals_mse: 0.6157 - total_corners_mse: 2.1919 - total_cards_mse: 1.0926 - val_loss: 2.7683 - val_result_loss: 1.0271 - val_total_goals_loss: 0.1182 - val_total_corners_loss: 0.9172 - val_total_cards_loss: 0.3021 - val_result_accuracy: 0.4926 - val_total_goals_mse: 0.1182 - val_total_corners_mse: 0.9172 - val_total_cards_mse: 0.3021
# Epoch 20/50
# 1322/1322 [==============================] - 9s 7ms/step - loss: 5.2936 - result_loss: 1.0375 - total_goals_loss: 0.6157 - total_corners_loss: 2.1757 - total_cards_loss: 1.0621 - result_accuracy: 0.4682 - total_goals_mse: 0.6157 - total_corners_mse: 2.1757 - total_cards_mse: 1.0621 - val_loss: 3.2644 - val_result_loss: 1.0226 - val_total_goals_loss: 0.2159 - val_total_corners_loss: 1.2119 - val_total_cards_loss: 0.4192 - val_result_accuracy: 0.5045 - val_total_goals_mse: 0.2159 - val_total_corners_mse: 1.2119 - val_total_cards_mse: 0.4192
# Epoch 21/50
# 1322/1322 [==============================] - 10s 7ms/step - loss: 5.1953 - result_loss: 1.0346 - total_goals_loss: 0.5923 - total_corners_loss: 2.1381 - total_cards_loss: 1.0321 - result_accuracy: 0.4705 - total_goals_mse: 0.5923 - total_corners_mse: 2.1381 - total_cards_mse: 1.0321 - val_loss: 2.8984 - val_result_loss: 1.0195 - val_total_goals_loss: 0.1385 - val_total_corners_loss: 1.0003 - val_total_cards_loss: 0.3505 - val_result_accuracy: 0.4670 - val_total_goals_mse: 0.1385 - val_total_corners_mse: 1.0003 - val_total_cards_mse: 0.3505
# Epoch 22/50
# 1322/1322 [==============================] - 9s 7ms/step - loss: 5.2069 - result_loss: 1.0330 - total_goals_loss: 0.5814 - total_corners_loss: 2.1692 - total_cards_loss: 1.0328 - result_accuracy: 0.4714 - total_goals_mse: 0.5814 - total_corners_mse: 2.1692 - total_cards_mse: 1.0328 - val_loss: 3.1829 - val_result_loss: 1.0122 - val_total_goals_loss: 0.1578 - val_total_corners_loss: 1.0406 - val_total_cards_loss: 0.5883 - val_result_accuracy: 0.5182 - val_total_goals_mse: 0.1578 - val_total_corners_mse: 1.0406 - val_total_cards_mse: 0.5883
# Epoch 23/50
# 1322/1322 [==============================] - 9s 7ms/step - loss: 5.1580 - result_loss: 1.0267 - total_goals_loss: 0.5740 - total_corners_loss: 2.1583 - total_cards_loss: 1.0090 - result_accuracy: 0.4771 - total_goals_mse: 0.5740 - total_corners_mse: 2.1583 - total_cards_mse: 1.0090 - val_loss: 2.9169 - val_result_loss: 1.0036 - val_total_goals_loss: 0.0957 - val_total_corners_loss: 1.0256 - val_total_cards_loss: 0.3979 - val_result_accuracy: 0.5112 - val_total_goals_mse: 0.0957 - val_total_corners_mse: 1.0256 - val_total_cards_mse: 0.3979
# Epoch 24/50
# 1322/1322 [==============================] - 9s 7ms/step - loss: 5.1000 - result_loss: 1.0181 - total_goals_loss: 0.5501 - total_corners_loss: 2.1458 - total_cards_loss: 1.0006 - result_accuracy: 0.4823 - total_goals_mse: 0.5501 - total_corners_mse: 2.1458 - total_cards_mse: 1.0006 - val_loss: 3.1186 - val_result_loss: 0.9925 - val_total_goals_loss: 0.1471 - val_total_corners_loss: 1.1747 - val_total_cards_loss: 0.4270 - val_result_accuracy: 0.4915 - val_total_goals_mse: 0.1471 - val_total_corners_mse: 1.1747 - val_total_cards_mse: 0.4270
# Epoch 25/50
# 1322/1322 [==============================] - 9s 7ms/step - loss: 5.0378 - result_loss: 1.0092 - total_goals_loss: 0.5449 - total_corners_loss: 2.1192 - total_cards_loss: 0.9841 - result_accuracy: 0.4856 - total_goals_mse: 0.5449 - total_corners_mse: 2.1192 - total_cards_mse: 0.9841 - val_loss: 3.0450 - val_result_loss: 0.9849 - val_total_goals_loss: 0.1779 - val_total_corners_loss: 1.0988 - val_total_cards_loss: 0.4006 - val_result_accuracy: 0.5256 - val_total_goals_mse: 0.1779 - val_total_corners_mse: 1.0988 - val_total_cards_mse: 0.4006
# Epoch 26/50
# 1322/1322 [==============================] - 10s 8ms/step - loss: 4.9900 - result_loss: 1.0065 - total_goals_loss: 0.5351 - total_corners_loss: 2.0867 - total_cards_loss: 0.9838 - result_accuracy: 0.4903 - total_goals_mse: 0.5351 - total_corners_mse: 2.0867 - total_cards_mse: 0.9838 - val_loss: 3.2192 - val_result_loss: 0.9811 - val_total_goals_loss: 0.2712 - val_total_corners_loss: 1.1333 - val_total_cards_loss: 0.4561 - val_result_accuracy: 0.5276 - val_total_goals_mse: 0.2712 - val_total_corners_mse: 1.1333 - val_total_cards_mse: 0.4561
# Epoch 27/50
# 1322/1322 [==============================] - 10s 7ms/step - loss: 5.0001 - result_loss: 1.0031 - total_goals_loss: 0.5269 - total_corners_loss: 2.1027 - total_cards_loss: 0.9920 - result_accuracy: 0.4905 - total_goals_mse: 0.5269 - total_corners_mse: 2.1027 - total_cards_mse: 0.9920 - val_loss: 3.1717 - val_result_loss: 0.9757 - val_total_goals_loss: 0.1943 - val_total_corners_loss: 1.0534 - val_total_cards_loss: 0.5776 - val_result_accuracy: 0.5268 - val_total_goals_mse: 0.1943 - val_total_corners_mse: 1.0534 - val_total_cards_mse: 0.5776
# Epoch 28/50
# 1322/1322 [==============================] - 9s 7ms/step - loss: 4.9732 - result_loss: 0.9989 - total_goals_loss: 0.5324 - total_corners_loss: 2.0879 - total_cards_loss: 0.9797 - result_accuracy: 0.4933 - total_goals_mse: 0.5324 - total_corners_mse: 2.0879 - total_cards_mse: 0.9797 - val_loss: 3.2536 - val_result_loss: 0.9700 - val_total_goals_loss: 0.1898 - val_total_corners_loss: 1.2824 - val_total_cards_loss: 0.4417 - val_result_accuracy: 0.5276 - val_total_goals_mse: 0.1898 - val_total_corners_mse: 1.2824 - val_total_cards_mse: 0.4417
# Epoch 29/50
# 1322/1322 [==============================] - 10s 8ms/step - loss: 4.9463 - result_loss: 0.9957 - total_goals_loss: 0.5333 - total_corners_loss: 2.0892 - total_cards_loss: 0.9584 - result_accuracy: 0.4945 - total_goals_mse: 0.5333 - total_corners_mse: 2.0892 - total_cards_mse: 0.9584 - val_loss: 3.1449 - val_result_loss: 0.9701 - val_total_goals_loss: 0.1279 - val_total_corners_loss: 1.1079 - val_total_cards_loss: 0.5656 - val_result_accuracy: 0.5263 - val_total_goals_mse: 0.1279 - val_total_corners_mse: 1.1079 - val_total_cards_mse: 0.5656
# Epoch 30/50
# 1322/1322 [==============================] - 11s 8ms/step - loss: 4.9836 - result_loss: 0.9921 - total_goals_loss: 0.5306 - total_corners_loss: 2.1028 - total_cards_loss: 0.9882 - result_accuracy: 0.4961 - total_goals_mse: 0.5306 - total_corners_mse: 2.1028 - total_cards_mse: 0.9882 - val_loss: 3.2244 - val_result_loss: 0.9648 - val_total_goals_loss: 0.1994 - val_total_corners_loss: 1.2496 - val_total_cards_loss: 0.4358 - val_result_accuracy: 0.5273 - val_total_goals_mse: 0.1994 - val_total_corners_mse: 1.2496 - val_total_cards_mse: 0.4358
# Epoch 31/50
# 1322/1322 [==============================] - 11s 8ms/step - loss: 5.0081 - result_loss: 0.9920 - total_goals_loss: 0.5239 - total_corners_loss: 2.1215 - total_cards_loss: 0.9991 - result_accuracy: 0.4949 - total_goals_mse: 0.5239 - total_corners_mse: 2.1215 - total_cards_mse: 0.9991 - val_loss: 2.8507 - val_result_loss: 0.9638 - val_total_goals_loss: 0.1683 - val_total_corners_loss: 0.9878 - val_total_cards_loss: 0.3613 - val_result_accuracy: 0.5275 - val_total_goals_mse: 0.1683 - val_total_corners_mse: 0.9878 - val_total_cards_mse: 0.3613
# Epoch 32/50
# 1322/1322 [==============================] - 10s 8ms/step - loss: 4.9029 - result_loss: 0.9894 - total_goals_loss: 0.5184 - total_corners_loss: 2.0706 - total_cards_loss: 0.9643 - result_accuracy: 0.4971 - total_goals_mse: 0.5184 - total_corners_mse: 2.0706 - total_cards_mse: 0.9643 - val_loss: 3.0330 - val_result_loss: 0.9649 - val_total_goals_loss: 0.1994 - val_total_corners_loss: 1.1230 - val_total_cards_loss: 0.3923 - val_result_accuracy: 0.5165 - val_total_goals_mse: 0.1994 - val_total_corners_mse: 1.1230 - val_total_cards_mse: 0.3923
# Epoch 33/50
# 1322/1322 [==============================] - 11s 8ms/step - loss: 4.8956 - result_loss: 0.9913 - total_goals_loss: 0.5234 - total_corners_loss: 2.0525 - total_cards_loss: 0.9742 - result_accuracy: 0.4970 - total_goals_mse: 0.5234 - total_corners_mse: 2.0525 - total_cards_mse: 0.9742 - val_loss: 3.1651 - val_result_loss: 0.9673 - val_total_goals_loss: 0.1241 - val_total_corners_loss: 1.2914 - val_total_cards_loss: 0.4317 - val_result_accuracy: 0.5187 - val_total_goals_mse: 0.1241 - val_total_corners_mse: 1.2914 - val_total_cards_mse: 0.4317
# Epoch 34/50
# 1322/1322 [==============================] - 12s 9ms/step - loss: 4.8680 - result_loss: 0.9893 - total_goals_loss: 0.5221 - total_corners_loss: 2.0272 - total_cards_loss: 0.9770 - result_accuracy: 0.4994 - total_goals_mse: 0.5221 - total_corners_mse: 2.0272 - total_cards_mse: 0.9770 - val_loss: 2.9557 - val_result_loss: 0.9650 - val_total_goals_loss: 0.1147 - val_total_corners_loss: 1.1179 - val_total_cards_loss: 0.4110 - val_result_accuracy: 0.5225 - val_total_goals_mse: 0.1147 - val_total_corners_mse: 1.1179 - val_total_cards_mse: 0.4110
# Epoch 35/50
# 1322/1322 [==============================] - 10s 7ms/step - loss: 4.9262 - result_loss: 0.9891 - total_goals_loss: 0.5354 - total_corners_loss: 2.0811 - total_cards_loss: 0.9736 - result_accuracy: 0.4972 - total_goals_mse: 0.5354 - total_corners_mse: 2.0811 - total_cards_mse: 0.9736 - val_loss: 3.1177 - val_result_loss: 0.9580 - val_total_goals_loss: 0.2049 - val_total_corners_loss: 1.1463 - val_total_cards_loss: 0.4558 - val_result_accuracy: 0.5271 - val_total_goals_mse: 0.2049 - val_total_corners_mse: 1.1463 - val_total_cards_mse: 0.4558
# Epoch 36/50
# 1322/1322 [==============================] - 10s 8ms/step - loss: 4.9101 - result_loss: 0.9859 - total_goals_loss: 0.5295 - total_corners_loss: 2.0589 - total_cards_loss: 0.9902 - result_accuracy: 0.4996 - total_goals_mse: 0.5295 - total_corners_mse: 2.0589 - total_cards_mse: 0.9902 - val_loss: 2.7972 - val_result_loss: 0.9603 - val_total_goals_loss: 0.1485 - val_total_corners_loss: 0.9235 - val_total_cards_loss: 0.4175 - val_result_accuracy: 0.5174 - val_total_goals_mse: 0.1485 - val_total_corners_mse: 0.9235 - val_total_cards_mse: 0.4175
# Epoch 37/50
# 1322/1322 [==============================] - 11s 8ms/step - loss: 4.9080 - result_loss: 0.9879 - total_goals_loss: 0.5188 - total_corners_loss: 2.0786 - total_cards_loss: 0.9738 - result_accuracy: 0.4978 - total_goals_mse: 0.5188 - total_corners_mse: 2.0786 - total_cards_mse: 0.9738 - val_loss: 2.8822 - val_result_loss: 0.9622 - val_total_goals_loss: 0.1540 - val_total_corners_loss: 1.0559 - val_total_cards_loss: 0.3605 - val_result_accuracy: 0.5230 - val_total_goals_mse: 0.1540 - val_total_corners_mse: 1.0559 - val_total_cards_mse: 0.3605
# Epoch 38/50
# 1322/1322 [==============================] - 10s 8ms/step - loss: 4.8519 - result_loss: 0.9869 - total_goals_loss: 0.5215 - total_corners_loss: 2.0432 - total_cards_loss: 0.9577 - result_accuracy: 0.5000 - total_goals_mse: 0.5215 - total_corners_mse: 2.0432 - total_cards_mse: 0.9577 - val_loss: 3.0471 - val_result_loss: 0.9614 - val_total_goals_loss: 0.1117 - val_total_corners_loss: 1.0079 - val_total_cards_loss: 0.6216 - val_result_accuracy: 0.5146 - val_total_goals_mse: 0.1117 - val_total_corners_mse: 1.0079 - val_total_cards_mse: 0.6216
# Epoch 39/50
# 1322/1322 [==============================] - 10s 8ms/step - loss: 4.9141 - result_loss: 0.9866 - total_goals_loss: 0.5265 - total_corners_loss: 2.0908 - total_cards_loss: 0.9646 - result_accuracy: 0.4996 - total_goals_mse: 0.5265 - total_corners_mse: 2.0908 - total_cards_mse: 0.9646 - val_loss: 2.8718 - val_result_loss: 0.9628 - val_total_goals_loss: 0.1352 - val_total_corners_loss: 1.0146 - val_total_cards_loss: 0.4149 - val_result_accuracy: 0.5142 - val_total_goals_mse: 0.1352 - val_total_corners_mse: 1.0146 - val_total_cards_mse: 0.4149
# Epoch 40/50
# 1322/1322 [==============================] - 10s 8ms/step - loss: 4.8844 - result_loss: 0.9843 - total_goals_loss: 0.5276 - total_corners_loss: 2.0597 - total_cards_loss: 0.9695 - result_accuracy: 0.4994 - total_goals_mse: 0.5276 - total_corners_mse: 2.0597 - total_cards_mse: 0.9695 - val_loss: 3.1045 - val_result_loss: 0.9629 - val_total_goals_loss: 0.2111 - val_total_corners_loss: 1.1829 - val_total_cards_loss: 0.4053 - val_result_accuracy: 0.5188 - val_total_goals_mse: 0.2111 - val_total_corners_mse: 1.1829 - val_total_cards_mse: 0.4053
# Epoch 41/50
# 1322/1322 [==============================] - 10s 7ms/step - loss: 4.8921 - result_loss: 0.9847 - total_goals_loss: 0.5215 - total_corners_loss: 2.0745 - total_cards_loss: 0.9684 - result_accuracy: 0.4994 - total_goals_mse: 0.5215 - total_corners_mse: 2.0745 - total_cards_mse: 0.9684 - val_loss: 2.6980 - val_result_loss: 0.9670 - val_total_goals_loss: 0.0852 - val_total_corners_loss: 0.9215 - val_total_cards_loss: 0.3812 - val_result_accuracy: 0.5090 - val_total_goals_mse: 0.0852 - val_total_corners_mse: 0.9215 - val_total_cards_mse: 0.3812
# Epoch 42/50
# 1322/1322 [==============================] - 10s 7ms/step - loss: 4.8762 - result_loss: 0.9835 - total_goals_loss: 0.5141 - total_corners_loss: 2.0641 - total_cards_loss: 0.9766 - result_accuracy: 0.4998 - total_goals_mse: 0.5141 - total_corners_mse: 2.0641 - total_cards_mse: 0.9766 - val_loss: 3.0548 - val_result_loss: 0.9619 - val_total_goals_loss: 0.1370 - val_total_corners_loss: 1.2017 - val_total_cards_loss: 0.4215 - val_result_accuracy: 0.5023 - val_total_goals_mse: 0.1370 - val_total_corners_mse: 1.2017 - val_total_cards_mse: 0.4215
# Epoch 43/50
# 1322/1322 [==============================] - 11s 8ms/step - loss: 4.8989 - result_loss: 0.9852 - total_goals_loss: 0.5221 - total_corners_loss: 2.0683 - total_cards_loss: 0.9844 - result_accuracy: 0.4990 - total_goals_mse: 0.5221 - total_corners_mse: 2.0683 - total_cards_mse: 0.9844 - val_loss: 2.7484 - val_result_loss: 0.9654 - val_total_goals_loss: 0.1156 - val_total_corners_loss: 0.9581 - val_total_cards_loss: 0.3679 - val_result_accuracy: 0.5176 - val_total_goals_mse: 0.1156 - val_total_corners_mse: 0.9581 - val_total_cards_mse: 0.3679
# Epoch 44/50
# 1322/1322 [==============================] - 13s 9ms/step - loss: 4.8561 - result_loss: 0.9850 - total_goals_loss: 0.5400 - total_corners_loss: 2.0245 - total_cards_loss: 0.9717 - result_accuracy: 0.4996 - total_goals_mse: 0.5400 - total_corners_mse: 2.0245 - total_cards_mse: 0.9717 - val_loss: 2.8956 - val_result_loss: 0.9576 - val_total_goals_loss: 0.1280 - val_total_corners_loss: 1.0295 - val_total_cards_loss: 0.4455 - val_result_accuracy: 0.5218 - val_total_goals_mse: 0.1280 - val_total_corners_mse: 1.0295 - val_total_cards_mse: 0.4455
# Epoch 45/50
# 1322/1322 [==============================] - 12s 9ms/step - loss: 4.8920 - result_loss: 0.9827 - total_goals_loss: 0.5186 - total_corners_loss: 2.0746 - total_cards_loss: 0.9834 - result_accuracy: 0.4992 - total_goals_mse: 0.5186 - total_corners_mse: 2.0746 - total_cards_mse: 0.9834 - val_loss: 3.0175 - val_result_loss: 0.9534 - val_total_goals_loss: 0.1953 - val_total_corners_loss: 1.1782 - val_total_cards_loss: 0.3596 - val_result_accuracy: 0.5278 - val_total_goals_mse: 0.1953 - val_total_corners_mse: 1.1782 - val_total_cards_mse: 0.3596
# Epoch 46/50
# 1322/1322 [==============================] - 11s 8ms/step - loss: 4.8995 - result_loss: 0.9831 - total_goals_loss: 0.5192 - total_corners_loss: 2.0897 - total_cards_loss: 0.9716 - result_accuracy: 0.5003 - total_goals_mse: 0.5192 - total_corners_mse: 2.0897 - total_cards_mse: 0.9716 - val_loss: 3.1234 - val_result_loss: 0.9537 - val_total_goals_loss: 0.1400 - val_total_corners_loss: 1.2753 - val_total_cards_loss: 0.4225 - val_result_accuracy: 0.5278 - val_total_goals_mse: 0.1400 - val_total_corners_mse: 1.2753 - val_total_cards_mse: 0.4225
# Epoch 47/50
# 1322/1322 [==============================] - 10s 8ms/step - loss: 4.8440 - result_loss: 0.9829 - total_goals_loss: 0.5171 - total_corners_loss: 2.0476 - total_cards_loss: 0.9653 - result_accuracy: 0.5003 - total_goals_mse: 0.5171 - total_corners_mse: 2.0476 - total_cards_mse: 0.9653 - val_loss: 2.9831 - val_result_loss: 0.9498 - val_total_goals_loss: 0.1903 - val_total_corners_loss: 1.1581 - val_total_cards_loss: 0.3567 - val_result_accuracy: 0.5270 - val_total_goals_mse: 0.1903 - val_total_corners_mse: 1.1581 - val_total_cards_mse: 0.3567
# Epoch 48/50
# 1322/1322 [==============================] - 10s 8ms/step - loss: 4.8584 - result_loss: 0.9829 - total_goals_loss: 0.5156 - total_corners_loss: 2.0656 - total_cards_loss: 0.9629 - result_accuracy: 0.4994 - total_goals_mse: 0.5156 - total_corners_mse: 2.0656 - total_cards_mse: 0.9629 - val_loss: 2.9489 - val_result_loss: 0.9611 - val_total_goals_loss: 0.1137 - val_total_corners_loss: 1.1377 - val_total_cards_loss: 0.4074 - val_result_accuracy: 0.5156 - val_total_goals_mse: 0.1137 - val_total_corners_mse: 1.1377 - val_total_cards_mse: 0.4074
# Epoch 49/50
# 1322/1322 [==============================] - 12s 9ms/step - loss: 4.8522 - result_loss: 0.9842 - total_goals_loss: 0.5248 - total_corners_loss: 2.0478 - total_cards_loss: 0.9684 - result_accuracy: 0.4996 - total_goals_mse: 0.5248 - total_corners_mse: 2.0478 - total_cards_mse: 0.9684 - val_loss: 2.7877 - val_result_loss: 0.9563 - val_total_goals_loss: 0.1659 - val_total_corners_loss: 0.9353 - val_total_cards_loss: 0.4005 - val_result_accuracy: 0.5276 - val_total_goals_mse: 0.1659 - val_total_corners_mse: 0.9353 - val_total_cards_mse: 0.4005
# Epoch 50/50
# 1322/1322 [==============================] - 11s 8ms/step - loss: 4.8583 - result_loss: 0.9828 - total_goals_loss: 0.5266 - total_corners_loss: 2.0414 - total_cards_loss: 0.9761 - result_accuracy: 0.5009 - total_goals_mse: 0.5266 - total_corners_mse: 2.0414 - total_cards_mse: 0.9761 - val_loss: 2.8184 - val_result_loss: 0.9556 - val_total_goals_loss: 0.1437 - val_total_corners_loss: 0.9388 - val_total_cards_loss: 0.4466 - val_result_accuracy: 0.5278 - val_total_goals_mse: 0.1437 - val_total_corners_mse: 0.9388 - val_total_cards_mse: 0.4466

# %% [markdown]
# ## Metrics

# %%
# Wizualizacja metryk

def plot_metrics(history, metric_name, title, ylim=5):
    plt.figure(figsize=(14, 6))
    plt.plot(history.history[metric_name])
    plt.plot(history.history['val_' + metric_name])
    plt.title(title)
    plt.ylabel(metric_name)
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.ylim(0, ylim)
    plt.show()

# Wizualizacja wyników treningu
plot_metrics(history, 'result_accuracy', 'Model Accuracy', ylim=1)
plot_metrics(history, 'result_loss', 'Result Loss', ylim=2)
plot_metrics(history, 'total_goals_loss', 'Total Goals Loss', ylim=2)
plot_metrics(history, 'total_corners_loss', 'Total Corners Loss', ylim=2)
plot_metrics(history, 'total_cards_loss', 'Total Cards Loss', ylim=2)

# Wizualizacja ogólnych strat
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Total Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['result_loss'])
plt.plot(history.history['val_result_loss'])
plt.title('Result Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
